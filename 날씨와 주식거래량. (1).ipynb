# %%
pip install pykrx
# Out:
# ...
#
# ...

# %%
from pykrx import stock
from pykrx import bond

# %%
df = stock.get_market_trading_volume_by_date("20191118", "20241011", "KOSPI")
print(df.head())
# Out:
#                 기관합계     기타법인        개인     외국인합계  전체
# 날짜
# 2019-11-18  -3434887  -138260   6637191  -3064044   0
# 2019-11-19  -4264808    59353  11931687  -7726232   0
# 2019-11-20  -3331186  1709376  18684096 -17062286   0
# 2019-11-21   3080985   603112  14923388 -18607485   0
# 2019-11-22 -10119617 -1507368  10987826    639159   0

# %%
df = df.drop(columns=['외국인합계','전체'])
print(df.head())
# Out:
#                 기관합계     기타법인        개인
# 날짜
# 2019-11-18  -3434887  -138260   6637191
# 2019-11-19  -4264808    59353  11931687
# 2019-11-20  -3331186  1709376  18684096
# 2019-11-21   3080985   603112  14923388
# 2019-11-22 -10119617 -1507368  10987826

# %%
print(df.head())
# Out:
#                 기관합계     기타법인        개인
# 날짜
# 2019-11-18  -3434887  -138260   6637191
# 2019-11-19  -4264808    59353  11931687
# 2019-11-20  -3331186  1709376  18684096
# 2019-11-21   3080985   603112  14923388
# 2019-11-22 -10119617 -1507368  10987826

# %%
df.to_csv(r'C:\Users\rltks\OneDrive\ドキュメント\주식거래량_cp949.csv', encoding='cp949')

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\rltks

# %%
pip install -U finance-datareader
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/89.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/89.3 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/89.3 kB ? eta -:--:--
#    ------------- -------------------------- 30.7/89.3 kB 262.6 kB/s eta 0:00:01
#    ------------------------------------ --- 81.9/89.3 kB 573.4 kB/s eta 0:00:01
#    ---------------------------------------- 89.3/89.3 kB 506.7 kB/s eta 0:00:00
# ...

# %%
import FinanceDataReader as fdr

# %%
from pykrx import stock
from pykrx import bond

# %%
df4 = fdr.DataReader("KOSPI","2019-11-18", "2024-10-24")
print(df4.head())
# Out:
#                Open     High      Low    Close     Volume  Change  UpDown  \
# Date
# 2019-11-18  2161.89  2165.89  2151.97  2160.69  489233053 -0.0007       2
# 2019-11-19  2151.04  2154.41  2137.01  2153.24  826885342 -0.0034       2
# 2019-11-20  2140.06  2145.97  2123.80  2125.32  581056092 -0.0130       2
# 2019-11-21  2123.65  2125.36  2088.19  2096.60  579554927 -0.0135       2
# 2019-11-22  2098.89  2106.42  2093.99  2101.96  519852004  0.0026       1
#
#              Comp         Amount            MarCap
# Date
# 2019-11-18  -1.49  4450920014374  1450349808632151
# 2019-11-19  -7.45  5605578491223  1446140184452898
# 2019-11-20 -27.92  5583376749873  1427359928536582
# 2019-11-21 -28.72  5437430115891  1407600550876970
# 2019-11-22   5.36  4310267738915  1411508256467062

# %%
df4 = df4.reset_index()
print(df4.head())
# Out:
#         Date     Open     High      Low    Close     Volume  Change  UpDown  \
# 0 2019-11-18  2161.89  2165.89  2151.97  2160.69  489233053 -0.0007       2
# 1 2019-11-19  2151.04  2154.41  2137.01  2153.24  826885342 -0.0034       2
# 2 2019-11-20  2140.06  2145.97  2123.80  2125.32  581056092 -0.0130       2
# 3 2019-11-21  2123.65  2125.36  2088.19  2096.60  579554927 -0.0135       2
# 4 2019-11-22  2098.89  2106.42  2093.99  2101.96  519852004  0.0026       1
#
#     Comp         Amount            MarCap
# 0  -1.49  4450920014374  1450349808632151
# 1  -7.45  5605578491223  1446140184452898
# 2 -27.92  5583376749873  1427359928536582
# 3 -28.72  5437430115891  1407600550876970
# 4   5.36  4310267738915  1411508256467062

# %%
df4.rename(columns={'Date': '날짜'}, inplace=True)

# %%
print(df4.head())
# Out:
#           날짜     Open     High      Low    Close     Volume  Change  UpDown  \
# 0 2019-11-18  2161.89  2165.89  2151.97  2160.69  489233053 -0.0007       2
# 1 2019-11-19  2151.04  2154.41  2137.01  2153.24  826885342 -0.0034       2
# 2 2019-11-20  2140.06  2145.97  2123.80  2125.32  581056092 -0.0130       2
# 3 2019-11-21  2123.65  2125.36  2088.19  2096.60  579554927 -0.0135       2
# 4 2019-11-22  2098.89  2106.42  2093.99  2101.96  519852004  0.0026       1
#
#     Comp         Amount            MarCap
# 0  -1.49  4450920014374  1450349808632151
# 1  -7.45  5605578491223  1446140184452898
# 2 -27.92  5583376749873  1427359928536582
# 3 -28.72  5437430115891  1407600550876970
# 4   5.36  4310267738915  1411508256467062

# %%
import pandas as pd

# %%
# 날짜를 기준으로 두 DataFrame 병합
df1 = pd.merge(df, df4, on='날짜', how='inner')

# %%
# 열 이름을 한글로 변경하기
df1.columns = [
    '날짜', 
    '기관합계', 
    '기타법인', 
    '개인', 
    '시가', 
    '고가', 
    '저가', 
    '종가', 
    '거래량', 
    '변동률', 
    '상승하락', 
    'Comp', 
    '거래금액', 
    '시가총액'
]

# 결과 확인
print(df1.head())
# Out:
#           날짜      기관합계     기타법인        개인       시가       고가       저가       종가  \
# 0 2019-11-18  -3434887  -138260   6637191  2161.89  2165.89  2151.97  2160.69
# 1 2019-11-19  -4264808    59353  11931687  2151.04  2154.41  2137.01  2153.24
# 2 2019-11-20  -3331186  1709376  18684096  2140.06  2145.97  2123.80  2125.32
# 3 2019-11-21   3080985   603112  14923388  2123.65  2125.36  2088.19  2096.60
# 4 2019-11-22 -10119617 -1507368  10987826  2098.89  2106.42  2093.99  2101.96
#
#          거래량     변동률  상승하락   Comp           거래금액              시가총액
# 0  489233053 -0.0007     2  -1.49  4450920014374  1450349808632151
# 1  826885342 -0.0034     2  -7.45  5605578491223  1446140184452898
# 2  581056092 -0.0130     2 -27.92  5583376749873  1427359928536582
# 3  579554927 -0.0135     2 -28.72  5437430115891  1407600550876970
# 4  519852004  0.0026     1   5.36  4310267738915  1411508256467062

# %%
df1.corr()
# Out:
#             날짜      기관합계      기타법인        개인        시가        고가        저가  \
# 날짜    1.000000  0.143585  0.057844 -0.186927  0.168462  0.162044  0.173241
# 기관합계  0.143585  1.000000 -0.082636 -0.674113 -0.026338 -0.020581 -0.012968
# 기타법인  0.057844 -0.082636  1.000000 -0.222316 -0.143468 -0.145682 -0.147210
# 개인   -0.186927 -0.674113 -0.222316  1.000000  0.020566  0.007692 -0.001116
# 시가    0.168462 -0.026338 -0.143468  0.020566  1.000000  0.999169  0.998674
# 고가    0.162044 -0.020581 -0.145682  0.007692  0.999169  1.000000  0.998583
# 저가    0.173241 -0.012968 -0.147210 -0.001116  0.998674  0.998583  1.000000
# 종가    0.166305 -0.007706 -0.149550 -0.011754  0.997608  0.998752  0.999129
# 거래량  -0.498418 -0.156819 -0.175455  0.183884  0.305810  0.312593  0.299155
# 변동률  -0.020170  0.369351 -0.075263 -0.564890 -0.023136 -0.003051  0.008729
# 상승하락  0.038088 -0.339200  0.058329  0.504068  0.029797  0.015909  0.007181
# ...

# %%
# '변동률', '상승하락', 'Comp' 열을 제거하기
columns_to_remove = ['변동률', '상승하락', 'Comp']
df_cleaned = df1.drop(columns=columns_to_remove)

# 결과 확인
print(df_cleaned.head())
# Out:
#           날짜      기관합계     기타법인        개인       시가       고가       저가       종가  \
# 0 2019-11-18  -3434887  -138260   6637191  2161.89  2165.89  2151.97  2160.69
# 1 2019-11-19  -4264808    59353  11931687  2151.04  2154.41  2137.01  2153.24
# 2 2019-11-20  -3331186  1709376  18684096  2140.06  2145.97  2123.80  2125.32
# 3 2019-11-21   3080985   603112  14923388  2123.65  2125.36  2088.19  2096.60
# 4 2019-11-22 -10119617 -1507368  10987826  2098.89  2106.42  2093.99  2101.96
#
#          거래량           거래금액              시가총액
# 0  489233053  4450920014374  1450349808632151
# 1  826885342  5605578491223  1446140184452898
# 2  581056092  5583376749873  1427359928536582
# 3  579554927  5437430115891  1407600550876970
# 4  519852004  4310267738915  1411508256467062

# %%
data = pd.read_csv('C:/Users/rltks/Downloads/OBS_ASOS_DD_20241015122913.csv', encoding='euc-kr')
data.head()
# Out:
#    지점 지점명          일시  평균기온(°C)  최저기온(°C)  최저기온 시각(hhmi)  최고기온(°C)  \
# 0  90  속초  2019-11-18       8.2       1.6         2344.0      14.2
# 1  90  속초  2019-11-19       2.0      -0.8          656.0       5.3
# 2  90  속초  2019-11-20       3.6      -1.2          720.0       8.5
# 3  90  속초  2019-11-21       6.5       0.7          411.0      11.2
# 4  90  속초  2019-11-22       9.3       4.6          653.0      15.3
#
#    최고기온 시각(hhmi)  강수 계속시간(hr)  10분 최다 강수량(mm)  10분 최다강수량 시각(hhmi)  \
# 0          605.0          NaN             NaN                 NaN
# 1         1444.0          NaN             NaN                 NaN
# 2         1453.0          NaN             NaN                 NaN
# 3         1351.0          NaN             NaN                 NaN
# 4         1226.0          NaN             NaN                 NaN
#
#    1시간 최다강수량(mm)  1시간 최다 강수량 시각(hhmi)  일강수량(mm)  최대 순간 풍속(m/s)  \
# 0            NaN                  NaN       7.4           15.5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171211 entries, 0 to 171210
# Data columns (total 61 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   지점                   171211 non-null  int64
#  1   지점명                  171211 non-null  object
#  2   일시                   171211 non-null  object
#  3   평균기온(°C)             170973 non-null  float64
#  4   최저기온(°C)             171115 non-null  float64
#  5   최저기온 시각(hhmi)        171116 non-null  float64
#  6   최고기온(°C)             171119 non-null  float64
#  7   최고기온 시각(hhmi)        171120 non-null  float64
#  8   강수 계속시간(hr)          16823 non-null   float64
#  9   10분 최다 강수량(mm)       43082 non-null   float64
#  10  10분 최다강수량 시각(hhmi)   29500 non-null   float64
#  11  1시간 최다강수량(mm)        43052 non-null   float64
#  12  1시간 최다 강수량 시각(hhmi)  30489 non-null   float64
#  13  일강수량(mm)             66230 non-null   float64
# ...

# %%
data.columns
# Out:
# Index(['지점', '지점명', '일시', '평균기온(°C)', '최저기온(°C)', '최저기온 시각(hhmi)', '최고기온(°C)',
#        '최고기온 시각(hhmi)', '강수 계속시간(hr)', '10분 최다 강수량(mm)', '10분 최다강수량 시각(hhmi)',
#        '1시간 최다강수량(mm)', '1시간 최다 강수량 시각(hhmi)', '일강수량(mm)', '최대 순간 풍속(m/s)',
#        '최대 순간 풍속 풍향(16방위)', '최대 순간풍속 시각(hhmi)', '최대 풍속(m/s)', '최대 풍속 풍향(16방위)',
#        '최대 풍속 시각(hhmi)', '평균 풍속(m/s)', '풍정합(100m)', '최다풍향(16방위)',
#        '평균 이슬점온도(°C)', '최소 상대습도(%)', '최소 상대습도 시각(hhmi)', '평균 상대습도(%)',
#        '평균 증기압(hPa)', '평균 현지기압(hPa)', '최고 해면기압(hPa)', '최고 해면기압 시각(hhmi)',
#        '최저 해면기압(hPa)', '최저 해면기압 시각(hhmi)', '평균 해면기압(hPa)', '가조시간(hr)',
#        '합계 일조시간(hr)', '1시간 최다일사 시각(hhmi)', '1시간 최다일사량(MJ/m2)', '합계 일사량(MJ/m2)',
#        '일 최심신적설(cm)', '일 최심신적설 시각(hhmi)', '일 최심적설(cm)', '일 최심적설 시각(hhmi)',
#        '합계 3시간 신적설(cm)', '평균 전운량(1/10)', '평균 중하층운량(1/10)', '평균 지면온도(°C)',
#        '최저 초상온도(°C)', '평균 5cm 지중온도(°C)', '평균 10cm 지중온도(°C)',
#        '평균 20cm 지중온도(°C)', '평균 30cm 지중온도(°C)', '0.5m 지중온도(°C)',
# ...

# %%
data['지점명'].unique()
# Out:
# array(['속초', '북춘천', '철원', '동두천', '파주', '대관령', '춘천', '백령도', '북강릉', '강릉',
#        '동해', '서울', '인천', '원주', '울릉도', '수원', '영월', '충주', '서산', '울진', '청주',
#        '대전', '추풍령', '안동', '상주', '포항', '군산', '대구', '전주', '울산', '창원', '광주',
#        '부산', '통영', '목포', '여수', '흑산도', '완도', '고창', '순천', '홍성', '서청주', '제주',
#        '고산', '성산', '서귀포', '진주', '강화', '양평', '이천', '인제', '홍천', '태백', '정선군',
#        '제천', '보은', '천안', '보령', '부여', '금산', '세종', '부안', '임실', '정읍', '남원',
#        '장수', '고창군', '영광군', '김해시', '순창군', '북창원', '양산시', '보성군', '강진군', '장흥',
#        '해남', '고흥', '의령군', '함양군', '광양시', '진도군', '봉화', '영주', '문경', '청송군',
#        '영덕', '의성', '구미', '영천', '경주시', '거창', '합천', '밀양', '산청', '거제', '남해',
#        '북부산'], dtype=object)

# %%
pip install xlsxwriter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# '일시' 열이 날짜 형식이 맞는지 확인하고 필요하면 변환
data['일시'] = pd.to_datetime(data['일시'], errors='coerce')

# 날짜별 전국 평균을 계산할 때 '일시'로 그룹핑하도록 수정
columns_to_average = [
       '평균기온(°C)', '최저기온(°C)', '최저기온 시각(hhmi)', '최고기온(°C)',
       '최고기온 시각(hhmi)', '강수 계속시간(hr)', '10분 최다 강수량(mm)', '10분 최다강수량 시각(hhmi)',
       '1시간 최다강수량(mm)', '1시간 최다 강수량 시각(hhmi)', '일강수량(mm)', '최대 순간 풍속(m/s)',
       '최대 순간 풍속 풍향(16방위)', '최대 순간풍속 시각(hhmi)', '최대 풍속(m/s)', '최대 풍속 풍향(16방위)',
       '최대 풍속 시각(hhmi)', '평균 풍속(m/s)', '풍정합(100m)', '최다풍향(16방위)',
       '평균 이슬점온도(°C)', '최소 상대습도(%)', '최소 상대습도 시각(hhmi)', '평균 상대습도(%)',
       '평균 증기압(hPa)', '평균 현지기압(hPa)', '최고 해면기압(hPa)', '최고 해면기압 시각(hhmi)',
       '최저 해면기압(hPa)', '최저 해면기압 시각(hhmi)', '평균 해면기압(hPa)', '가조시간(hr)',
       '합계 일조시간(hr)', '1시간 최다일사 시각(hhmi)', '1시간 최다일사량(MJ/m2)', '합계 일사량(MJ/m2)',
       '일 최심신적설(cm)', '일 최심신적설 시각(hhmi)', '일 최심적설(cm)', '일 최심적설 시각(hhmi)',
       '합계 3시간 신적설(cm)', '평균 전운량(1/10)', '평균 중하층운량(1/10)', '평균 지면온도(°C)',
       '최저 초상온도(°C)', '평균 5cm 지중온도(°C)', '평균 10cm 지중온도(°C)',
       '평균 20cm 지중온도(°C)', '평균 30cm 지중온도(°C)', '0.5m 지중온도(°C)',
       '1.0m 지중온도(°C)', '1.5m 지중온도(°C)', '3.0m 지중온도(°C)', '5.0m 지중온도(°C)',
       '합계 대형증발량(mm)', '합계 소형증발량(mm)', '9-9강수(mm)', '안개 계속시간(hr)'
    ]

# '일시' 기준으로 전국 평균을 계산
nationwide_mean = data.groupby('일시')[columns_to_average].mean().reset_index()

# '전국'이라는 지점명 추가
nationwide_mean['지점명'] = '전국'

# 기존 데이터프레임에 전국 평균 데이터를 추가
final_df = pd.concat([data, nationwide_mean], ignore_index=True)

# '지점명'을 맨 앞으로 재정렬 (원하는 대로 컬럼 순서를 조정)
final_df = final_df[['일시', '지점명'] + columns_to_average]

# 최종 데이터 출력
print(final_df.head())
# Out:
#           일시 지점명  평균기온(°C)  최저기온(°C)  최저기온 시각(hhmi)  최고기온(°C)  최고기온 시각(hhmi)  \
# 0 2019-11-18  속초       8.2       1.6         2344.0      14.2          605.0
# 1 2019-11-19  속초       2.0      -0.8          656.0       5.3         1444.0
# 2 2019-11-20  속초       3.6      -1.2          720.0       8.5         1453.0
# 3 2019-11-21  속초       6.5       0.7          411.0      11.2         1351.0
# 4 2019-11-22  속초       9.3       4.6          653.0      15.3         1226.0
#
#    강수 계속시간(hr)  10분 최다 강수량(mm)  10분 최다강수량 시각(hhmi)  1시간 최다강수량(mm)  \
# 0          NaN             NaN                 NaN            NaN
# 1          NaN             NaN                 NaN            NaN
# 2          NaN             NaN                 NaN            NaN
# 3          NaN             NaN                 NaN            NaN
# 4          NaN             NaN                 NaN            NaN
#
#    1시간 최다 강수량 시각(hhmi)  일강수량(mm)  최대 순간 풍속(m/s)  최대 순간 풍속 풍향(16방위)  \
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173001 entries, 0 to 173000
# Data columns (total 60 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   일시                   173001 non-null  datetime64[ns]
#  1   지점명                  173001 non-null  object
#  2   평균기온(°C)             172763 non-null  float64
#  3   최저기온(°C)             172905 non-null  float64
#  4   최저기온 시각(hhmi)        172906 non-null  float64
#  5   최고기온(°C)             172909 non-null  float64
#  6   최고기온 시각(hhmi)        172910 non-null  float64
#  7   강수 계속시간(hr)          18355 non-null   float64
#  8   10분 최다 강수량(mm)       44023 non-null   float64
#  9   10분 최다강수량 시각(hhmi)   30321 non-null   float64
#  10  1시간 최다강수량(mm)        43993 non-null   float64
#  11  1시간 최다 강수량 시각(hhmi)  31317 non-null   float64
#  12  일강수량(mm)             67826 non-null   float64
#  13  최대 순간 풍속(m/s)        172763 non-null  float64
# ...

# %%
# 시각이 포함된 열 목록
remove_time_columns = ['최저기온 시각(hhmi)', '최고기온 시각(hhmi)', '10분 최다강수량 시각(hhmi)', 
                       '1시간 최다 강수량 시각(hhmi)', '최대 순간풍속 시각(hhmi)', 
                       '최대 풍속 시각(hhmi)', 
                       '최고 해면기압 시각(hhmi)', '최저 해면기압 시각(hhmi)','최소 상대습도 시각(hhmi)', 
                       '1시간 최다일사 시각(hhmi)', '일 최심신적설 시각(hhmi)', 
                       '일 최심적설 시각(hhmi)', '1시간 최다 강수량 시각(hhmi)', 
                       ]

# 데이터프레임에서 제거
final_df = final_df.drop(columns=remove_time_columns)

# 결과 출력
print(final_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173001 entries, 0 to 173000
# Data columns (total 48 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   일시                 173001 non-null  datetime64[ns]
#  1   지점명                173001 non-null  object
#  2   평균기온(°C)           172763 non-null  float64
#  3   최저기온(°C)           172905 non-null  float64
#  4   최고기온(°C)           172909 non-null  float64
#  5   강수 계속시간(hr)        18355 non-null   float64
#  6   10분 최다 강수량(mm)     44023 non-null   float64
#  7   1시간 최다강수량(mm)      43993 non-null   float64
#  8   일강수량(mm)           67826 non-null   float64
#  9   최대 순간 풍속(m/s)      172763 non-null  float64
#  10  최대 순간 풍속 풍향(16방위)  172764 non-null  float64
#  11  최대 풍속(m/s)         172763 non-null  float64
#  12  최대 풍속 풍향(16방위)     172769 non-null  float64
#  13  평균 풍속(m/s)         172713 non-null  float64
#  14  풍정합(100m)          172696 non-null  float64
# ...

# %%
final_df['지점명'].unique()
# Out:
# array(['속초', '북춘천', '철원', '동두천', '파주', '대관령', '춘천', '백령도', '북강릉', '강릉',
#        '동해', '서울', '인천', '원주', '울릉도', '수원', '영월', '충주', '서산', '울진', '청주',
#        '대전', '추풍령', '안동', '상주', '포항', '군산', '대구', '전주', '울산', '창원', '광주',
#        '부산', '통영', '목포', '여수', '흑산도', '완도', '고창', '순천', '홍성', '서청주', '제주',
#        '고산', '성산', '서귀포', '진주', '강화', '양평', '이천', '인제', '홍천', '태백', '정선군',
#        '제천', '보은', '천안', '보령', '부여', '금산', '세종', '부안', '임실', '정읍', '남원',
#        '장수', '고창군', '영광군', '김해시', '순창군', '북창원', '양산시', '보성군', '강진군', '장흥',
#        '해남', '고흥', '의령군', '함양군', '광양시', '진도군', '봉화', '영주', '문경', '청송군',
#        '영덕', '의성', '구미', '영천', '경주시', '거창', '합천', '밀양', '산청', '거제', '남해',
#        '북부산', '전국'], dtype=object)

# %%
print(final_df.head())
# Out:
#           일시 지점명  평균기온(°C)  최저기온(°C)  최고기온(°C)  강수 계속시간(hr)  10분 최다 강수량(mm)  \
# 0 2019-11-18  속초       8.2       1.6      14.2          NaN             NaN
# 1 2019-11-19  속초       2.0      -0.8       5.3          NaN             NaN
# 2 2019-11-20  속초       3.6      -1.2       8.5          NaN             NaN
# 3 2019-11-21  속초       6.5       0.7      11.2          NaN             NaN
# 4 2019-11-22  속초       9.3       4.6      15.3          NaN             NaN
#
#    1시간 최다강수량(mm)  일강수량(mm)  최대 순간 풍속(m/s)  최대 순간 풍속 풍향(16방위)  최대 풍속(m/s)  \
# 0            NaN       7.4           15.5              290.0         7.5
# 1            NaN       NaN           13.7              270.0         7.2
# 2            NaN       NaN            5.5              270.0         3.0
# 3            NaN       NaN            4.3              290.0         2.7
# 4            NaN       NaN            4.1              140.0         2.2
#
#    최대 풍속 풍향(16방위)  평균 풍속(m/s)  풍정합(100m)  최다풍향(16방위)  평균 이슬점온도(°C)  \
# ...

# %%
# '전국'만 남기고 나머지 지점 제거
final_df = final_df[final_df['지점명'] == '전국']

# 최종 데이터 출력
print(final_df)
# Out:
#                일시 지점명   평균기온(°C)   최저기온(°C)   최고기온(°C)  강수 계속시간(hr)  \
# 171211 2019-11-18  전국   8.809474   3.525263  16.567368     6.021304
# 171212 2019-11-19  전국   3.866316   0.802105   7.153684     3.084615
# 171213 2019-11-20  전국   2.764211  -1.855789   8.907368     6.520000
# 171214 2019-11-21  전국   5.224211  -2.316842  12.430526          NaN
# 171215 2019-11-22  전국   9.445263   3.009474  17.486316          NaN
# 171216 2019-11-23  전국  10.854737   4.662105  18.287368     0.910909
# 171217 2019-11-24  전국  12.756842   7.643158  19.308421     3.576957
# 171218 2019-11-25  전국   6.011702   3.453684  10.816842     7.992857
# 171219 2019-11-26  전국   7.802128   2.625532  13.487368     7.332000
# 171220 2019-11-27  전국   6.352128   2.811579   9.822105     5.716667
# 171221 2019-11-28  전국   4.958947   0.618947  10.565263    10.946667
# 171222 2019-11-29  전국   3.582979  -0.867368   9.925263     8.800000
# 171223 2019-11-30  전국   5.568085  -1.506316  12.818947     2.335455
# ...

# %%
missing_values = final_df.isnull().sum()
print("결측치 개수:")
print(missing_values)
# Out:
# 결측치 개수:
# 일시                      0
# 지점명                     0
# 평균기온(°C)                0
# 최저기온(°C)                0
# 최고기온(°C)                0
# 강수 계속시간(hr)           258
# 10분 최다 강수량(mm)        849
# 1시간 최다강수량(mm)         849
# 일강수량(mm)              194
# 최대 순간 풍속(m/s)           0
# 최대 순간 풍속 풍향(16방위)       0
# 최대 풍속(m/s)              0
# 최대 풍속 풍향(16방위)          0
# 평균 풍속(m/s)              0
# 풍정합(100m)               0
# 최다풍향(16방위)              0
# 평균 이슬점온도(°C)            0
# 최소 상대습도(%)              0
# 평균 상대습도(%)              0
# 평균 증기압(hPa)             0
# 평균 현지기압(hPa)            0
# 최고 해면기압(hPa)            0
# 최저 해면기압(hPa)            0
# 평균 해면기압(hPa)            0
# 가조시간(hr)                0
# 합계 일조시간(hr)             0
# 1시간 최다일사량(MJ/m2)        0
# 합계 일사량(MJ/m2)           0
# 일 최심신적설(cm)          1532
# 일 최심적설(cm)           1437
# 합계 3시간 신적설(cm)       1531
# 평균 전운량(1/10)            0
# 평균 중하층운량(1/10)          0
# 평균 지면온도(°C)             0
# 최저 초상온도(°C)             0
# ...

# %%
import pandas as pd

# 지중온도 결측치 채우기 (앞뒤 평균값)
ground_temp_cols = ['0.5m 지중온도(°C)', '1.0m 지중온도(°C)', '1.5m 지중온도(°C)']
final_df[ground_temp_cols] = final_df[ground_temp_cols].fillna(final_df[ground_temp_cols].rolling(window=2, min_periods=1).mean())

# 나머지 결측치를 0으로 채우기
other_cols = ['강수 계속시간(hr)', '10분 최다 강수량(mm)',
              '1시간 최다강수량(mm)', '일강수량(mm)', 
              '일 최심신적설(cm)', '일 최심적설(cm)', '합계 3시간 신적설(cm)', '9-9강수(mm)', 
              '안개 계속시간(hr)', '합계 대형증발량(mm)', '합계 소형증발량(mm)']

final_df[other_cols] = final_df[other_cols].fillna(0)

# 결측치 개수 확인
print(final_df.isnull().sum())
# Out:
# 일시                   0
# 지점명                  0
# 평균기온(°C)             0
# 최저기온(°C)             0
# 최고기온(°C)             0
# 강수 계속시간(hr)          0
# 10분 최다 강수량(mm)       0
# 1시간 최다강수량(mm)        0
# 일강수량(mm)             0
# 최대 순간 풍속(m/s)        0
# 최대 순간 풍속 풍향(16방위)    0
# 최대 풍속(m/s)           0
# 최대 풍속 풍향(16방위)       0
# 평균 풍속(m/s)           0
# 풍정합(100m)            0
# 최다풍향(16방위)           0
# 평균 이슬점온도(°C)         0
# 최소 상대습도(%)           0
# 평균 상대습도(%)           0
# 평균 증기압(hPa)          0
# 평균 현지기압(hPa)         0
# 최고 해면기압(hPa)         0
# 최저 해면기압(hPa)         0
# 평균 해면기압(hPa)         0
# 가조시간(hr)             0
# 합계 일조시간(hr)          0
# 1시간 최다일사량(MJ/m2)     0
# 합계 일사량(MJ/m2)        0
# 일 최심신적설(cm)          0
# 일 최심적설(cm)           0
# 합계 3시간 신적설(cm)       0
# 평균 전운량(1/10)         0
# 평균 중하층운량(1/10)       0
# 평균 지면온도(°C)          0
# 최저 초상온도(°C)          0
# 평균 5cm 지중온도(°C)      0
# 평균 10cm 지중온도(°C)     0
# 평균 20cm 지중온도(°C)     0
# 평균 30cm 지중온도(°C)     0
# 0.5m 지중온도(°C)        0
# ...

# %%
import pandas as pd

# 예시 데이터프레임 (이 부분은 실제 데이터프레임으로 대체하세요)
# final_df = pd.DataFrame({...})

# '일시' 열을 변환하기
final_df['일시'] = pd.to_datetime(final_df['일시'], unit='ns')

# 변환 결과 확인
print(final_df[['일시']].head())
# Out:
#                일시
# 171211 2019-11-18
# 171212 2019-11-19
# 171213 2019-11-20
# 171214 2019-11-21
# 171215 2019-11-22

# %%
final_df.head()
# Out:
#                일시 지점명  평균기온(°C)  최저기온(°C)   최고기온(°C)  강수 계속시간(hr)  \
# 171211 2019-11-18  전국  8.809474  3.525263  16.567368     6.021304
# 171212 2019-11-19  전국  3.866316  0.802105   7.153684     3.084615
# 171213 2019-11-20  전국  2.764211 -1.855789   8.907368     6.520000
# 171214 2019-11-21  전국  5.224211 -2.316842  12.430526     0.000000
# 171215 2019-11-22  전국  9.445263  3.009474  17.486316     0.000000
#
#         10분 최다 강수량(mm)  1시간 최다강수량(mm)   일강수량(mm)  최대 순간 풍속(m/s)  \
# 171211             0.0            0.0  12.380000      13.000000
# 171212             0.0            0.0   0.183784      11.072632
# 171213             0.0            0.0   0.200000       6.835789
# 171214             0.0            0.0   0.000000       5.189474
# 171215             0.0            0.0   0.000000       5.469474
#
#         최대 순간 풍속 풍향(16방위)  최대 풍속(m/s)  최대 풍속 풍향(16방위)  평균 풍속(m/s)  \
# 171211         272.631579    7.677895      276.000000    3.880000
# ...

# %%
# '일시' 열을 '날짜'로 변경
final_df.rename(columns={'일시': '날짜'}, inplace=True)

# 결과 확인
print(final_df.head())
# Out:
#                날짜 지점명  평균기온(°C)  최저기온(°C)   최고기온(°C)  강수 계속시간(hr)  \
# 171211 2019-11-18  전국  8.809474  3.525263  16.567368     6.021304
# 171212 2019-11-19  전국  3.866316  0.802105   7.153684     3.084615
# 171213 2019-11-20  전국  2.764211 -1.855789   8.907368     6.520000
# 171214 2019-11-21  전국  5.224211 -2.316842  12.430526     0.000000
# 171215 2019-11-22  전국  9.445263  3.009474  17.486316     0.000000
#
#         10분 최다 강수량(mm)  1시간 최다강수량(mm)   일강수량(mm)  최대 순간 풍속(m/s)  \
# 171211             0.0            0.0  12.380000      13.000000
# 171212             0.0            0.0   0.183784      11.072632
# 171213             0.0            0.0   0.200000       6.835789
# 171214             0.0            0.0   0.000000       5.189474
# 171215             0.0            0.0   0.000000       5.469474
#
#         최대 순간 풍속 풍향(16방위)  최대 풍속(m/s)  최대 풍속 풍향(16방위)  평균 풍속(m/s)  \
# 171211         272.631579    7.677895      276.000000    3.880000
# ...

# %%
# 주식 데이터에서 날짜 목록 가져오기
stock_dates = df_cleaned.index

# 날씨 데이터에서 주식 거래량과 같은 날짜만 선택하기
filtered_weather_data = final_df[final_df.index.isin(stock_dates)]

# 결과 출력
print(filtered_weather_data)
# Out:
# Empty DataFrame
# Columns: [날짜, 지점명, 평균기온(°C), 최저기온(°C), 최고기온(°C), 강수 계속시간(hr), 10분 최다 강수량(mm), 1시간 최다강수량(mm), 일강수량(mm), 최대 순간 풍속(m/s), 최대 순간 풍속 풍향(16방위), 최대 풍속(m/s), 최대 풍속 풍향(16방위), 평균 풍속(m/s), 풍정합(100m), 최다풍향(16방위), 평균 이슬점온도(°C), 최소 상대습도(%), 평균 상대습도(%), 평균 증기압(hPa), 평균 현지기압(hPa), 최고 해면기압(hPa), 최저 해면기압(hPa), 평균 해면기압(hPa), 가조시간(hr), 합계 일조시간(hr), 1시간 최다일사량(MJ/m2), 합계 일사량(MJ/m2), 일 최심신적설(cm), 일 최심적설(cm), 합계 3시간 신적설(cm), 평균 전운량(1/10), 평균 중하층운량(1/10), 평균 지면온도(°C), 최저 초상온도(°C), 평균 5cm 지중온도(°C), 평균 10cm 지중온도(°C), 평균 20cm 지중온도(°C), 평균 30cm 지중온도(°C), 0.5m 지중온도(°C), 1.0m 지중온도(°C), 1.5m 지중온도(°C), 3.0m 지중온도(°C), 5.0m 지중온도(°C), 합계 대형증발량(mm), 합계 소형증발량(mm), 9-9강수(mm), 안개 계속시간(hr)]
# Index: []

# %%
df.rename(columns={'Date': '날짜'}, inplace=True)

# %%
# 날짜를 기준으로 두 DataFrame 병합
df1 = pd.merge(final_df,df_cleaned, on='날짜', how='inner')

# %%
df1.head()
# Out:
#           날짜 지점명  평균기온(°C)  최저기온(°C)   최고기온(°C)  강수 계속시간(hr)  10분 최다 강수량(mm)  \
# 0 2019-11-18  전국  8.809474  3.525263  16.567368     6.021304             0.0
# 1 2019-11-19  전국  3.866316  0.802105   7.153684     3.084615             0.0
# 2 2019-11-20  전국  2.764211 -1.855789   8.907368     6.520000             0.0
# 3 2019-11-21  전국  5.224211 -2.316842  12.430526     0.000000             0.0
# 4 2019-11-22  전국  9.445263  3.009474  17.486316     0.000000             0.0
#
#    1시간 최다강수량(mm)   일강수량(mm)  최대 순간 풍속(m/s)  최대 순간 풍속 풍향(16방위)  최대 풍속(m/s)  \
# 0            0.0  12.380000      13.000000         272.631579    7.677895
# 1            0.0   0.183784      11.072632         285.578947    6.254737
# 2            0.0   0.200000       6.835789         246.736842    4.097895
# 3            0.0   0.000000       5.189474         141.789474    3.287368
# 4            0.0   0.000000       5.469474         142.315789    3.472632
#
# ...

# %%
df1 = df1.drop(columns=['지점명'])

# %%
df1.head()
# Out:
#           날짜  평균기온(°C)  최저기온(°C)   최고기온(°C)  강수 계속시간(hr)  10분 최다 강수량(mm)  \
# 0 2019-11-18  8.809474  3.525263  16.567368     6.021304             0.0
# 1 2019-11-19  3.866316  0.802105   7.153684     3.084615             0.0
# 2 2019-11-20  2.764211 -1.855789   8.907368     6.520000             0.0
# 3 2019-11-21  5.224211 -2.316842  12.430526     0.000000             0.0
# 4 2019-11-22  9.445263  3.009474  17.486316     0.000000             0.0
#
#    1시간 최다강수량(mm)   일강수량(mm)  최대 순간 풍속(m/s)  최대 순간 풍속 풍향(16방위)  최대 풍속(m/s)  \
# 0            0.0  12.380000      13.000000         272.631579    7.677895
# 1            0.0   0.183784      11.072632         285.578947    6.254737
# 2            0.0   0.200000       6.835789         246.736842    4.097895
# 3            0.0   0.000000       5.189474         141.789474    3.287368
# 4            0.0   0.000000       5.469474         142.315789    3.472632
#
#    최대 풍속 풍향(16방위)  평균 풍속(m/s)    풍정합(100m)  최다풍향(16방위)  평균 이슬점온도(°C)  \
# ...

# %%
df1.columns
# Out:
# Index(['날짜', '평균기온(°C)', '최저기온(°C)', '최고기온(°C)', '강수 계속시간(hr)',
#        '10분 최다 강수량(mm)', '1시간 최다강수량(mm)', '일강수량(mm)', '최대 순간 풍속(m/s)',
#        '최대 순간 풍속 풍향(16방위)', '최대 풍속(m/s)', '최대 풍속 풍향(16방위)', '평균 풍속(m/s)',
#        '풍정합(100m)', '최다풍향(16방위)', '평균 이슬점온도(°C)', '최소 상대습도(%)', '평균 상대습도(%)',
#        '평균 증기압(hPa)', '평균 현지기압(hPa)', '최고 해면기압(hPa)', '최저 해면기압(hPa)',
#        '평균 해면기압(hPa)', '가조시간(hr)', '합계 일조시간(hr)', '1시간 최다일사량(MJ/m2)',
#        '합계 일사량(MJ/m2)', '일 최심신적설(cm)', '일 최심적설(cm)', '합계 3시간 신적설(cm)',
#        '평균 전운량(1/10)', '평균 중하층운량(1/10)', '평균 지면온도(°C)', '최저 초상온도(°C)',
#        '평균 5cm 지중온도(°C)', '평균 10cm 지중온도(°C)', '평균 20cm 지중온도(°C)',
#        '평균 30cm 지중온도(°C)', '0.5m 지중온도(°C)', '1.0m 지중온도(°C)', '1.5m 지중온도(°C)',
#        '3.0m 지중온도(°C)', '5.0m 지중온도(°C)', '합계 대형증발량(mm)', '합계 소형증발량(mm)',
#        '9-9강수(mm)', '안개 계속시간(hr)', '기관합계', '기타법인', '개인', '시가', '고가', '저가',
#        '종가', '거래량', '거래금액', '시가총액'],
#       dtype='object')

# %%
df1.rename(columns={'기관합계': '기관합계 거래량', '기타법인': '기타법인 거래량','개인':'개인 거래량', '거래량': '총 거래량'}, inplace=True)

print(df1)
# Out:
#              날짜   평균기온(°C)   최저기온(°C)   최고기온(°C)  강수 계속시간(hr)  10분 최다 강수량(mm)  \
# 0    2019-11-18   8.809474   3.525263  16.567368     6.021304        0.000000
# 1    2019-11-19   3.866316   0.802105   7.153684     3.084615        0.000000
# 2    2019-11-20   2.764211  -1.855789   8.907368     6.520000        0.000000
# 3    2019-11-21   5.224211  -2.316842  12.430526     0.000000        0.000000
# 4    2019-11-22   9.445263   3.009474  17.486316     0.000000        0.000000
# 5    2019-11-25   6.011702   3.453684  10.816842     7.992857        0.000000
# 6    2019-11-26   7.802128   2.625532  13.487368     7.332000        0.000000
# 7    2019-11-27   6.352128   2.811579   9.822105     5.716667        0.000000
# 8    2019-11-28   4.958947   0.618947  10.565263    10.946667        0.000000
# 9    2019-11-29   3.582979  -0.867368   9.925263     8.800000        0.000000
# 10   2019-12-02   3.760638   0.416842   7.013684     2.357059        0.000000
# ...

# %%
selected_columns = [
   '날짜', '평균기온(°C)', '최저기온(°C)', '최고기온(°C)', '강수 계속시간(hr)',
       '10분 최다 강수량(mm)', '1시간 최다강수량(mm)', '일강수량(mm)', '최대 순간 풍속(m/s)',
       '최대 순간 풍속 풍향(16방위)', '최대 풍속(m/s)', '최대 풍속 풍향(16방위)', '평균 풍속(m/s)',
       '풍정합(100m)', '최다풍향(16방위)', '평균 이슬점온도(°C)', '최소 상대습도(%)', '평균 상대습도(%)',
       '평균 증기압(hPa)', '평균 현지기압(hPa)', '최고 해면기압(hPa)', '최저 해면기압(hPa)',
       '평균 해면기압(hPa)', '가조시간(hr)', '합계 일조시간(hr)', '1시간 최다일사량(MJ/m2)',
       '합계 일사량(MJ/m2)', '일 최심신적설(cm)', '일 최심적설(cm)', '합계 3시간 신적설(cm)',
       '평균 전운량(1/10)', '평균 중하층운량(1/10)', '평균 지면온도(°C)', '최저 초상온도(°C)',
       '평균 5cm 지중온도(°C)', '평균 10cm 지중온도(°C)', '평균 20cm 지중온도(°C)',
       '평균 30cm 지중온도(°C)', '0.5m 지중온도(°C)', '1.0m 지중온도(°C)', '1.5m 지중온도(°C)',
       '3.0m 지중온도(°C)', '5.0m 지중온도(°C)', '합계 대형증발량(mm)', '합계 소형증발량(mm)',
       '9-9강수(mm)', '안개 계속시간(hr)', '기관합계 거래량', '기타법인 거래량', '개인 거래량', '시가', '고가', '저가',
       '종가', '총 거래량', '거래금액', '시가총액'
]

# 선택한 변수들로 DataFrame 필터링
correlation_data = df1[selected_columns]

# 상관계수 행렬 계산
correlation_matrix = correlation_data.corr()

# 생략 없이 전체 출력되도록 설정
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

print(correlation_matrix)

# 설정을 원래대로 되돌리기
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
# Out:
#                          날짜  평균기온(°C)  최저기온(°C)  최고기온(°C)  강수 계속시간(hr)  \
# 날짜                 1.000000  0.186285  0.181065  0.186241    -0.001073
# 평균기온(°C)           0.186285  1.000000  0.985481  0.984892    -0.061988
# 최저기온(°C)           0.181065  0.985481  1.000000  0.944350     0.043625
# 최고기온(°C)           0.186241  0.984892  0.944350  1.000000    -0.180731
# 강수 계속시간(hr)       -0.001073 -0.061988  0.043625 -0.180731     1.000000
# 10분 최다 강수량(mm)     0.110323  0.562498  0.614613  0.493427     0.344907
# 1시간 최다강수량(mm)      0.082987  0.512051  0.566403  0.439351     0.412877
# 일강수량(mm)           0.043906  0.325365  0.389781  0.239743     0.632917
# 최대 순간 풍속(m/s)     -0.056195 -0.225642 -0.194024 -0.268898     0.266804
# 최대 순간 풍속 풍향(16방위) -0.114301 -0.444201 -0.448080 -0.423856    -0.132952
# 최대 풍속(m/s)        -0.107178 -0.259471 -0.231776 -0.297291     0.250283
# 최대 풍속 풍향(16방위)    -0.118478 -0.464121 -0.466600 -0.443868    -0.133399
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# VIF 계산 함수
def calculate_vif(X):
    vif = pd.DataFrame()
    vif["Variable"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif

# 독립 변수 선택
X = df1[[ '평균기온(°C)','강수 계속시간(hr)',
          '10분 최다 강수량(mm)', '1시간 최다강수량(mm)', '일강수량(mm)', '최대 풍속(m/s)',
          '풍정합(100m)',
          '평균 상대습도(%)', '최고 해면기압(hPa)', '합계 일사량(MJ/m2)', '일 최심신적설(cm)', '일 최심적설(cm)',
          '합계 3시간 신적설(cm)', '평균 전운량(1/10)', '평균 중하층운량(1/10)', '5.0m 지중온도(°C)', '9-9강수(mm)', '안개 계속시간(hr)', 
          '시가', '거래금액', '시가총액']]

# 초기 VIF 계산
vif_df = calculate_vif(X)

# VIF가 높은 변수 필터링 (예: 10 이상인 경우)
high_vif = vif_df[vif_df["VIF"] > 10]
print(high_vif)
# Out:
# Empty DataFrame
# Columns: [Variable, VIF]
# Index: []

# %%
# VIF 계산
vif_data = pd.DataFrame()
vif_data["Variable"] = X2.columns
vif_data["VIF"] = [variance_inflation_factor(X2.values, i) for i in range(X2.shape[1])]

print("\n다중공선성 확인 (VIF):")
print(vif_data)
# Out:
# 다중공선성 확인 (VIF):
#           Variable       VIF
# 0            const  0.000000
# 1             거래금액  1.030852
# 2         평균기온(°C)  1.937150
# 3      강수 계속시간(hr)  3.003816
# 4         일강수량(mm)  3.331331
# 5        풍정합(100m)  1.287778
# 6       일 최심적설(cm)  1.247563
# 7   합계 3시간 신적설(cm)  1.465322
# 8   평균 중하층운량(1/10)  1.928584
# 9    5.0m 지중온도(°C)  1.146616
# 10       9-9강수(mm)  2.370078
# 11     안개 계속시간(hr)  1.274680
# C:\Users\rltks\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1781: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# 데이터프레임 df1을 불러옵니다. (이미 전처리된 상태라고 가정)
# df1 = pd.read_csv('your_data.csv')

# 독립 변수와 종속 변수를 설정합니다.
# 첫 번째 모델: 거래금액으로만 회귀 분석
independent_vars_1 = ['거래금액']
dependent_var = '총 거래량'  # 분석할 종속 변수

X1 = df1[independent_vars_1]
y = df1[dependent_var]

# 상수항 추가
X1 = sm.add_constant(X1)

# 회귀 모델 적합
model_1 = sm.OLS(y, X1).fit()

# 두 번째 모델: 날씨 변수 포함
independent_vars_2 = independent_vars_1 + [
    '평균기온(°C)', '강수 계속시간(hr)', '일강수량(mm)', 
    '풍정합(100m)', '일 최심적설(cm)', '합계 3시간 신적설(cm)', 
    '평균 중하층운량(1/10)', '5.0m 지중온도(°C)', '9-9강수(mm)', 
    '안개 계속시간(hr)'
]

# 날씨 변수 데이터 준비
X2 = df1[independent_vars_2].dropna()

# 상수항 추가
X2 = sm.add_constant(X2)

# 데이터 정규화
scaler = StandardScaler()
X2_scaled = scaler.fit_transform(X2)

# PCA 적용
pca = PCA(n_components=0.95)  # 95%의 분산을 보존
X2_pca = pca.fit_transform(X2_scaled)

# PCA 변환 후 상수항 추가
X2_pca_with_const = sm.add_constant(X2_pca)

# 회귀 모델 적합
model_2 = sm.OLS(y.loc[X2.index], X2_pca_with_const).fit()  # y 값을 인덱스 조정하여 일치시킴

# 결과 출력
print("첫 번째 모델 (날씨 데이터 제외):")
print(model_1.summary())
print("\n두 번째 모델 (날씨 데이터 포함, PCA 적용):")
print(model_2.summary())
# Out:
# 첫 번째 모델 (날씨 데이터 제외):
#                             OLS Regression Results
# ...
# Dep. Variable:                  총 거래량   R-squared:                       0.409
# Model:                            OLS   Adj. R-squared:                  0.408
# Method:                 Least Squares   F-statistic:                     831.8
# Date:                Tue, 05 Nov 2024   Prob (F-statistic):          1.70e-139
# Time:                        00:27:38   Log-Likelihood:                -25131.
# No. Observations:                1206   AIC:                         5.027e+04
# Df Residuals:                    1204   BIC:                         5.028e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.153e+08   2.23e+07      5.162      0.000    7.15e+07    1.59e+08
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# 데이터프레임 df1을 불러옵니다. (이미 전처리된 상태라고 가정)
# df1 = pd.read_csv('your_data.csv')

# 독립 변수와 종속 변수를 설정합니다.
# 첫 번째 모델: 거래금액으로만 회귀 분석
independent_vars_1 = ['거래금액']
dependent_var = '개인 거래량'  # 분석할 종속 변수

X1 = df1[independent_vars_1]
y = df1[dependent_var]

# 상수항 추가
X1 = sm.add_constant(X1)

# 회귀 모델 적합
model_1 = sm.OLS(y, X1).fit()

# 두 번째 모델: 날씨 변수 포함
independent_vars_2 = independent_vars_1 + [
    '평균기온(°C)', '강수 계속시간(hr)', '일강수량(mm)', 
    '풍정합(100m)', '일 최심적설(cm)', '합계 3시간 신적설(cm)', 
    '평균 중하층운량(1/10)', '5.0m 지중온도(°C)', '9-9강수(mm)', 
    '안개 계속시간(hr)'
]

# 날씨 변수 데이터 준비
X2 = df1[independent_vars_2].dropna()

# 상수항 추가
X2 = sm.add_constant(X2)

# 데이터 정규화
scaler = StandardScaler()
X2_scaled = scaler.fit_transform(X2)

# PCA 적용
pca = PCA(n_components=0.95)  # 95%의 분산을 보존
X2_pca = pca.fit_transform(X2_scaled)

# PCA 변환 후 상수항 추가
X2_pca_with_const = sm.add_constant(X2_pca)

# 회귀 모델 적합
model_2 = sm.OLS(y.loc[X2.index], X2_pca_with_const).fit()  # y 값을 인덱스 조정하여 일치시킴

# 결과 출력
print("첫 번째 모델 (날씨 데이터 제외):")
print(model_1.summary())
print("\n두 번째 모델 (날씨 데이터 포함, PCA 적용):")
print(model_2.summary())
# Out:
# 첫 번째 모델 (날씨 데이터 제외):
#                             OLS Regression Results
# ...
# Dep. Variable:                 개인 거래량   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     26.62
# Date:                Tue, 05 Nov 2024   Prob (F-statistic):           2.89e-07
# Time:                        10:09:01   Log-Likelihood:                -21778.
# No. Observations:                1206   AIC:                         4.356e+04
# Df Residuals:                    1204   BIC:                         4.357e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.146e+06   1.39e+06     -2.270      0.023   -5.86e+06   -4.27e+05
# ...
